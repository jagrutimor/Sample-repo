# %% [markdown]
# <a href="https://colab.research.google.com/github/jagrutimor/Sample-repo/blob/main/Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This contains all libraries imported for out program

# %%
import numpy as np
import pandas as pd
import matplotlib
# Out:
# 3.7.1
# 2.0.3
# [1 2 3]

# %% [markdown]
# Basic operations using libraries like numpy,pandas and matplotlib

# %%
print(matplotlib.__version__)
print(pd.__version__)
arr=np.array([1,2,3])
print(arr)
